# %%
import torch as th
path = '/data/mint/SkelAg/training/'
a = th.load(f"{path}/heatmap_64x64_with_single_sample/0/0.pth", weights_only=False)
b = th.load(f"{path}/heatmap_64x64_with_single/0/3.pth", weights_only=False)
c = th.load(f"{path}/heatmap_64x64_with_single_sample_2/0/0.pth", weights_only=False)
d = th.load(f"{path}/heatmap_64x64_with_single_2/0/3.pth", weights_only=False)

lat_a = a[0][0]['latents']
lat_b = b[0][0]['latents']
lat_c = c[0][0]['latents']
lat_d = d[0][0]['latents']

print(a[0][0]['num_frames'])
print(c[0][0]['num_frames'])

print(lat_a.shape, lat_b.shape, lat_c.shape, lat_d.shape)
print(th.allclose(lat_a, lat_b))
print(th.allclose(lat_a, lat_c))
print(th.allclose(lat_b, lat_d))
print(th.sum(lat_a - lat_b))
print(th.mean(lat_a - lat_b))
print(th.mean(lat_a - lat_c))
print(th.mean(lat_b - lat_d))
print(th.mean(lat_a), th.mean(lat_b))
# Out:
# dict_keys(['input_video', 'height', 'width', 'num_frames', 'cfg_scale', 'tiled', 'tile_size', 'tile_stride', 'rand_device', 'use_gradient_checkpointing', 'use_gradient_checkpointing_offload', 'cfg_merge', 'vace_scale', 'max_timestep_boundary', 'min_timestep_boundary', 'preferred_timestep_id', 'preferred_dit_block_id', 'joints_3d', 'joints_2d', 'cams_intr', 'cams_extr', 'joint_names', 'bones', 'noise', 'latents', 'input_latents', 'vace_context', 'animate_pose_video', 'animate_face_video', 'animate_inpaint_video', 'animate_mask_video'])
# torch.Size([1, 16, 16, 8, 8]) torch.Size([1, 16, 16, 8, 8]) torch.Size([1, 16, 16, 8, 8]) torch.Size([1, 16, 16, 8, 8])
# False
# False
# False
# tensor(-438., device='cuda:0', dtype=torch.bfloat16)
# tensor(-0.0267, device='cuda:0', dtype=torch.bfloat16)
# tensor(-0.0265, device='cuda:0', dtype=torch.bfloat16)
# tensor(-0.0031, device='cuda:0', dtype=torch.bfloat16)
# tensor(-0.0190, device='cuda:0', dtype=torch.bfloat16) tensor(0.0078, device='cuda:0', dtype=torch.bfloat16)
